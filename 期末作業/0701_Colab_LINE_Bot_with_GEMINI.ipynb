# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 26.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 10.8 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://amigo-capable-untying.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://amigo-capable-untying.ngrok-free.dev
# True

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="什麼是AI AGENT？"
)
print(response.text)
# Out:
# AI Agent（人工智慧代理人）是一個非常重要的概念，它代表了AI技術從單純的數據處理和模式識別，發展到能夠**自主地感知、決策、行動並達成特定目標**的更高層次。
#
# 簡單來說，一個AI Agent就是一個**能夠在其環境中自主運作，並透過感知、思考、規劃和行動來實現其目標的AI系統**。
#
# ### AI Agent 的核心要素：
#
# 1.  **感知 (Perception)**：
#     *   Agent 必須能夠「觀察」或「接收」其操作環境中的資訊。這可以是透過感測器（如攝影機、麥克風、觸摸感測器）在物理世界中，或者透過API、資料庫、網頁內容、使用者輸入等在數位世界中。
#
# 2.  **決策 (Decision-Making) / 思考 (Thinking)**：
#     *   在感知到環境資訊後，Agent 會利用其內建的AI模型（可能是傳統的邏輯規則、機器學習模型、深度學習模型，甚至是大型語言模型LLM）來處理這些資訊，評估當前狀態，並決定下一步的最佳行動方案。這通常涉及規劃、推理和預測。
#
# 3.  **行動 (Action)**：
#     *   根據其決策，Agent 會執行一個或多個動作，以試圖改變環境狀態或推進其目標。這可以是物理動作（如移動機器人手臂、駕駛汽車），也可以是數位動作（如發送電子郵件、更新資料庫、執行程式碼、生成文字）。
#
# 4.  **環境 (Environment)**：
#     *   Agent 運作的空間。這可以是物理世界（例如一個房間、一條道路），也可以是數位世界（例如一個軟體系統、網際網路、一個虛擬遊戲）。
#
# 5.  **目標 (Goals)**：
#     *   Agent 存在的目的。它所有的感知、決策和行動都是為了達成這些預設的目標。目標可以是明確的（如「把包裹送到指定地點」），也可以是抽象的（如「最大化使用者滿意度」）。
#
# ### AI Agent 與一般 AI 的區別：
#
# *   **自主性 (Autonomy)**：這是最關鍵的區別。AI Agent 被設計為在很大程度上無需持續的人類干預就能執行任務和達成目標。而許多傳統的AI系統（例如一個圖像分類器）需要明確的輸入才能產生輸出。
# *   **主動性 (Proactivity)**：Agent 不僅僅是被動地響應指令，它也能主動地採取行動來實現其目標。
# *   **目標導向 (Goal-Oriented)**：Agent 的行為都圍繞著實現其目標而展開。
# *   **適應性 (Adaptability)**：許多先進的Agent 能夠從經驗中學習，並根據環境變化調整其行為。
#
# ### AI Agent 的工作流程 (Agent Loop)：
#
# 典型的 AI Agent 會不斷循環以下過程：
#
# 1.  **感知**：從環境中收集新的資訊。
# 2.  **理解/分析**：處理這些資訊，理解環境的當前狀態。
# 3.  **規劃**：根據目標和當前狀態，制定行動計畫。
# 4.  **執行**：執行計畫中的一個或多個動作。
# 5.  **監控/重複**：觀察行動的結果，並返回步驟1，再次感知環境，以調整或繼續執行計畫。
#
# ### AI Agent 的例子：
#
# *   **智能助理**：Siri、Google Assistant、Alexa 等。它們感知你的語音指令，理解你的意圖，執行搜尋、播放音樂、設定鬧鐘等動作。
# *   **自動駕駛汽車**：它感知周圍的道路、車輛、行人（感測器），決策駕駛路線和速度（AI演算法），然後控制方向盤、油門和剎車（行動）以將乘客安全送達目的地。
# *   **推薦系統**：雖然不總是完全自主，但先進的推薦系統可以看作是Agent。它們感知你的歷史行為和偏好，決策推薦哪些商品或內容，並透過展示推薦列表來「行動」。
# *   **工業機器人**：感知生產線上的產品狀態，決策如何操作（如抓取、組裝），然後執行物理動作。
# *   **聊天機器人 (Chatbot)**：特別是那些能進行多輪對話、理解複雜意圖並能調用外部工具的進階聊天機器人，它們感知用戶的輸入，利用LLM決策如何回應或執行任務，並生成文字或觸發API來「行動」。
# *   **AI 遊戲角色 (NPC)**：在遊戲中，AI 控制的非玩家角色感知遊戲世界的狀態，決策下一步行動（攻擊、躲藏、完成任務），然後在遊戲中執行這些動作。
# *   **金融交易機器人**：感知市場數據，決策買賣策略，然後執行交易指令。
# *   **Web Scraper/Crawler**：感知網頁內容，決策抓取哪些資訊，然後訪問更多網頁並提取數據。
#
# 總之，AI Agent 代表了讓 AI 系統具備更強的「自主性」和「目的性」的能力，使其能夠在複雜的環境中獨立運作並完成任務，是許多未來 AI 應用（如通用人工智慧、智能機器人、智慧自動化）的基石。隨著大型語言模型（LLM）的興起，AI Agent 的能力更是得到了極大的提升，使其能夠處理更複雜的規劃和更廣泛的任務。

# %%
def stateless_query(payload):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=payload
    )
    return response.text

# %%
result = stateless_query("簡介明新科技大學")
print(result)
# Out:
# 明新科技大學（Mingshin University of Science and Technology, 簡稱明新科大）是一所位於新竹縣新豐鄉的私立科技大學。
#
# 以下是其簡要介紹：
#
# 1.  **創校歷史與特色：**
#     *   創立於**1966年**，前身為「明新工業專科學校」，是**臺灣第一所私立工業專科學校**，擁有悠久的辦學歷史與豐富的技術教育經驗。
#     *   於1999年改制為科技大學，持續深耕技職教育。
#
# 2.  **地理位置優勢：**
#     *   地處**新竹科學園區**周邊，與在地高科技產業連結緊密，為其產學合作、學生實習與畢業就業提供了極佳的環境與機會。
#
# 3.  **辦學理念與目標：**
#     *   秉持「**務實致用**」的教育理念，致力於培養具備專業技能、實作能力、創新思維及職場競爭力的優質人才。
#     *   強調理論與實務並重，鼓勵學生考取專業證照。
#
# 4.  **學院與學系：**
#     *   目前設有**工程學院**、**管理學院**、**服務事業學院**和**設計學院**等四大院，提供多種學士班、碩士班及進修推廣教育學程。
#     *   各學院下設有工程、電機、資管、企管、休閒、幼保、旅館、設計等多元學系，以符合不同產業的人才需求。
#
# 5.  **教學特色與成果：**
#     *   **產學合作密切：** 積極與企業界合作，推動建教合作、校外實習、專題研究，讓學生提早接觸職場。
#     *   **實務導向教學：** 投入資源建置各類專業實驗室與實訓基地，提供學生完善的實作環境。
#     *   **高就業率：** 畢業生因具備扎實的專業技能與實務經驗，受到企業界肯定，擁有良好的就業表現。
#     *   **創新創業：** 鼓勵學生參與創新創業競賽，培養解決問題與創新思維的能力。
#
# 總結來說，明新科技大學是一所歷史悠久、地理位置優越、以「務實致用」為導向的綜合型科技大學，旨在培養符合產業需求、具備職場競爭力的專業人才。

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
)

app = Flask(__name__)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)


@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    text = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)
        if text.startswith('AI '): #避免會容易被認為官方帳號是用Gemini模型回應
            prompt = text[3:]
            reply_text = stateless_query(prompt)
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=reply_text)]
                )
            )

        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=event.message.text),
                        TextMessage(text=event.message.text)]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# BODY:  {"destination":"U712d2d53b4bcdc15fe49feed703ea8a8","events":[{"type":"message","message":{"type":"text","id":"615029602628403669","quoteToken":"acr2cMuaUWwTKpu2Ecebe3fISL1yTHkAvG4Hrid-mM6bnTXoS-E7tmROnfAz0T0wa95_A_xZDrdWTU6LaZ1QuSx7XYxOASjjYajSuh82BR-JoD_6EciEfT7rQ-0Vueq0DSDr1AjdEXWzSRb8UBlz4g","markAsReadToken":"g-BvLDbs7cPNohXTLedH-qTXlrrMye-EJBIx-MY1n2FUSvP7ZNol_-VpmESVK-qLUFbVz5DApo7L_NhK0_kQoh4JKG_lAU2eV_EWPecyFqMuedQn7j4Cs02d_TppMYGylq2h4evloHjuM1cIKT8hPRIByZrKRVw29on99Y9RmCN5KmKHcuaUAaQ16YHHiIbcWDLynMBkcYrzlz9q4uhbuQ","text":"AI 請你簡單用五點來介紹AI Agent是做什麼"},"webhookEventId":"01KS6RS0D00T6T2Y1GR9P3ABMY","deliveryContext":{"isRedelivery":false},"timestamp":1779417513924,"source":{"type":"user","userId":"U2a89fc3db06801f30d432e1507e0ee19"},"replyToken":"549be4bee22a4bf8aea4f68757de1e3f","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [22/May/2026 02:38:42] "POST / HTTP/1.1" 200 -
# WARNING:pyngrok.process.ngrok:t=2026-05-22T02:39:09+0000 lvl=warn msg="Stopping forwarder" name=linebot_tunnel acceptErr="failed to accept connection: Listener closed"
# WARNING:pyngrok.process.ngrok:t=2026-05-22T02:39:09+0000 lvl=warn msg="Error restarting forwarder" name=linebot_tunnel err="failed to start tunnel: remote gone away"
